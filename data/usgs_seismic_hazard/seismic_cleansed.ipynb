# %%
# !pip install geopandas

import geopandas as gpd

# %%
import geopandas as gpd
import pandas as pd


df_seismic = pd.read_csv('usgs_seismic_hazard_by_county.csv')
df_seismic
# Out:
#       geoid  state_fips  county_fips          county_name state_abbr  \
# 0      1003           1            3       Baldwin County         AL
# 1      1007           1            7          Bibb County         AL
# 2      1009           1            9        Blount County         AL
# 3      1001           1            1       Autauga County         AL
# 4      1005           1            5       Barbour County         AL
# ...     ...         ...          ...                  ...        ...
# 3215  72145          72          145  Vega Baja Municipio         PR
# 3216  72147          72          147    Vieques Municipio         PR
# 3217  72149          72          149   Villalba Municipio         PR
# 3218  72151          72          151    Yabucoa Municipio         PR
# 3219  72153          72          153      Yauco Municipio         PR
#
#       centroid_lat  centroid_lon  pga_max_considered  ss_spectral_02s  \
# ...

# %%
df_seismic['state_fips'].value_counts()
# Out:
# state_fips
# 48    254
# 13    159
# 51    133
# 21    120
# 29    115
# 20    105
# 17    102
# 37    100
# 19     99
# 47     95
# 31     93
# 18     92
# 39     88
# 27     87
# 26     83
# 28     82
# 40     77
# 72     77
# 5      75
# 55     72
# 42     67
# 1      67
# 12     67
# 46     66
# 22     64
# 8      64
# 36     62
# 6      58
# 30     56
# 54     55
# 38     53
# 45     46
# 16     44
# 53     39
# 41     36
# 35     33
# 2      29
# 49     29
# 24     24
# 56     23
# 34     21
# 32     17
# 23     16
# 4      15
# 25     14
# 50     14
# 33     10
# 9       9
# 44      5
# 15      5
# 10      3
# 11      1
# Name: count, dtype: int64

# %%
df_seismic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3220 entries, 0 to 3219
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   geoid               3220 non-null   int64
#  1   state_fips          3220 non-null   int64
#  2   county_fips         3220 non-null   int64
#  3   county_name         3220 non-null   object
#  4   state_abbr          3220 non-null   object
#  5   centroid_lat        3220 non-null   float64
#  6   centroid_lon        3220 non-null   float64
#  7   pga_max_considered  3220 non-null   float64
#  8   ss_spectral_02s     3220 non-null   float64
#  9   s1_spectral_1s      3220 non-null   float64
#  10  sds_design          3220 non-null   float64
#  11  sd1_design          3220 non-null   float64
#  12  risk_coeff_pga      0 non-null      float64
# dtypes: float64(8), int64(3), object(2)
# memory usage: 327.2+ KB

# %%
df_seismic['risk_coeff_pga']
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#         ..
# 3215   NaN
# 3216   NaN
# 3217   NaN
# 3218   NaN
# 3219   NaN
# Name: risk_coeff_pga, Length: 3220, dtype: float64

# %%
df_seismic = df_seismic.drop(columns=['risk_coeff_pga'])

# %%
df_seismic[df_seismic.duplicated()]
# Out:
# Empty DataFrame
# Columns: [geoid, state_fips, county_fips, county_name, state_abbr, centroid_lat, centroid_lon, pga_max_considered, ss_spectral_02s, s1_spectral_1s, sds_design, sd1_design]
# Index: []

# %%
import matplotlib.pyplot as plt

columns_to_plot = ['pga_max_considered', 'ss_spectral_02s', 's1_spectral_1s', 'sds_design', 'sd1_design']
df_seismic[columns_to_plot].boxplot()
# Out:
# <Axes: >

# %%
df_seismic
# Out:
#       geoid  state_fips  county_fips          county_name state_abbr  \
# 0      1003           1            3       Baldwin County         AL
# 1      1007           1            7          Bibb County         AL
# 2      1009           1            9        Blount County         AL
# 3      1001           1            1       Autauga County         AL
# 4      1005           1            5       Barbour County         AL
# ...     ...         ...          ...                  ...        ...
# 3215  72145          72          145  Vega Baja Municipio         PR
# 3216  72147          72          147    Vieques Municipio         PR
# 3217  72149          72          149   Villalba Municipio         PR
# 3218  72151          72          151    Yabucoa Municipio         PR
# 3219  72153          72          153      Yauco Municipio         PR
#
#       centroid_lat  centroid_lon  pga_max_considered  ss_spectral_02s  \
# ...

# %%
df_seismic.isnull().sum()
# Out:
# geoid                 0
# state_fips            0
# county_fips           0
# county_name           0
# state_abbr            0
# centroid_lat          0
# centroid_lon          0
# pga_max_considered    0
# ss_spectral_02s       0
# s1_spectral_1s        0
# sds_design            0
# sd1_design            0
# dtype: int64

# %% [markdown]
# - Removed the column 'risk_coeff_pga', where all values are missing
# - check outliers and missing values
