# %%
import geopandas

# %%
military_boundaries_data = geopandas.read_file("../processed_data/military_boundaries.geojson")
military_boundaries_data
# Out:
#      object_id              country_name                     feature_name  \
# 0            1  United States of America          NAVMEDCEN Portsmouth VA
# 1            2  United States of America      NAVSUPPACT Hampton Roads VA
# 2            3  United States of America                  NNSY South Gate
# 3            4  United States of America      Naval Support Activity Wash
# 4            5  United States of America            Arlington Service Ctr
# ..         ...                       ...                              ...
# 738       1691  United States of America  Joint Base Elmendorf-Richardson
# 739       1703  United States of America           Haarp Research Station
# 740       1709  United States of America        Joint Base Langley-Eustis
# 741       1714  United States of America         Joint Base Lewis-McChord
# 742       1731  United States of America   Joint Base Myer-Henderson Hall
#
#     installation_id is_joint_base                       site_name  \
# ...
